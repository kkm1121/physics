# %% [markdown]
# <a href="https://colab.research.google.com/github/kkm1121/physics/blob/20250522/20250522.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

m = 0.15
r = 0.60
f = 2.0

T = 1/f
v = (2*math.pi*r)/T
ac = (v*v)/r

print("(a) 주기 T = ",T,"s")
print("(b) 속력 v = ", round (v,2),"m/s")
print("(c) 가속도 ac = ", round (ac,2),"m/s^2")
# Out:
# (a) 주기 T = 0.5 s
# (b) 속력 v = 7.54 m/s
# (c) 가속도 ac = 94.75 m/s^2

# %%
from sympy import symbols, Eq, sin, cos, tan, atan, solve, simplify

m, g, r, v, T, theta = symbols('m g r v T theta')

eq1 = Eq(T * sin(theta), m * v**2 / r)
eq2 = Eq(T * cos(theta), m * g)

tan_theta = simplify((m * v**2 / r) / (m * g))
theta_expr = atan(tan_theta)

print("1번 tan(θ) = ", tan_theta)
print("θ = ", theta_expr)

m, g, r, v, T, theta, ac = symbols('m g r v T theta ac')

g = 9.8

tan_theta_expr = ac / g

eq = Eq(tan_theta_expr, 1)

ac_solution = solve(eq, ac)[0]

print("2번 tan(θ) = ac / g")
print("θ = 45, tan(θ) = 1")
print("ac = ", round(ac_solution,1),"m/s^2")
# Out:
# 1번 tan(θ) = v**2/(g*r)
# θ = atan(v**2/(g*r))
# 2번 tan(θ) = ac / g
# θ = 45, tan(θ) = 1
# ac = 9.8 m/s^2

# %%
import math

v = 32
t = 10.5
at = v/t
print("접선가속도:", round(at,2),"m/s^2")

v = 35
r = 500
ar = (v*v)/r
print("지름가속도:",ar,"m/s^2")
# Out:
# 접선가속도: 3.05 m/s^2
# 지름가속도: 2.45 m/s^2
